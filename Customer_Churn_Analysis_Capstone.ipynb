# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("muhammadshahidazeem/customer-churn-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\danai\.cache\kagglehub\datasets\muhammadshahidazeem\customer-churn-dataset\versions\1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('customer_churn_dataset-training-master.csv')

# %%
df.head(10)
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
# 5         8.0  51.0    Male    33.0             25.0            9.0
# 6         9.0  58.0  Female    49.0             12.0            3.0
# 7        10.0  55.0  Female    37.0              8.0            4.0
# 8        11.0  39.0    Male    12.0              5.0            7.0
# 9        12.0  64.0  Female     3.0             25.0            2.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
# 5           26.0           Premium          Annual        129.0
# 6           16.0          Standard       Quarterly        821.0
# 7           15.0           Premium          Annual        445.0
# 8            4.0          Standard       Quarterly        969.0
# 9           11.0          Standard       Quarterly        415.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0
# 5               8.0    1.0
# 6              24.0    1.0
# 7              30.0    1.0
# 8              13.0    1.0
# 9              29.0    1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 440832 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  object
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  object
#  8   Contract Length    440832 non-null  object
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 43.7+ MB

# %%
df.describe().round(2)
# Out:
#        CustomerID        Age     Tenure  Usage Frequency  Support Calls  \
# count   440832.00  440832.00  440832.00        440832.00      440832.00
# mean    225398.67      39.37      31.26            15.81           3.60
# std     129531.92      12.44      17.26             8.59           3.07
# min          2.00      18.00       1.00             1.00           0.00
# 25%     113621.75      29.00      16.00             9.00           1.00
# 50%     226125.50      39.00      32.00            16.00           3.00
# 75%     337739.25      48.00      46.00            23.00           6.00
# max     449999.00      65.00      60.00            30.00          10.00
#
#        Payment Delay  Total Spend  Last Interaction      Churn
# count      440832.00    440832.00         440832.00  440832.00
# mean           12.97       631.62             14.48       0.57
# std             8.26       240.80              8.60       0.50
# min             0.00       100.00              1.00       0.00
# 25%             6.00       480.00              7.00       0.00
# 50%            12.00       661.00             14.00       1.00
# 75%            19.00       830.00             22.00       1.00
# max            30.00      1000.00             30.00       1.00

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
columns_of_interest = ['Age', 'Gender', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Subscription Type',
                       'Contract Length', 'Total Spend', 'Last Interaction', 'Churn']

# %%
df[columns_of_interest].describe()
# Out:
#                  Age         Tenure  Usage Frequency  Support Calls  \
# count  440832.000000  440832.000000    440832.000000  440832.000000
# mean       39.373153      31.256336        15.807494       3.604437
# std        12.442369      17.255727         8.586242       3.070218
# min        18.000000       1.000000         1.000000       0.000000
# 25%        29.000000      16.000000         9.000000       1.000000
# 50%        39.000000      32.000000        16.000000       3.000000
# 75%        48.000000      46.000000        23.000000       6.000000
# max        65.000000      60.000000        30.000000      10.000000
#
#        Payment Delay    Total Spend  Last Interaction          Churn
# count  440832.000000  440832.000000     440832.000000  440832.000000
# mean       12.965722     631.616223         14.480868       0.567107
# std         8.258063     240.803001          8.596208       0.495477
# min         0.000000     100.000000          1.000000       0.000000
# 25%         6.000000     480.000000          7.000000       0.000000
# 50%        12.000000     661.000000         14.000000       1.000000
# 75%        19.000000     830.000000         22.000000       1.000000
# max        30.000000    1000.000000         30.000000       1.000000

# %%
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
display(df[['Age', 'Churn']])
# Out:
#          Age  Churn
# 0       30.0    1.0
# 1       65.0    1.0
# 2       55.0    1.0
# 3       58.0    1.0
# 4       23.0    1.0
# ...      ...    ...
# 440828  42.0    0.0
# 440829  25.0    0.0
# 440830  26.0    0.0
# 440831  28.0    0.0
# 440832  31.0    0.0
#
# [440833 rows x 2 columns]

# %%
sns.boxplot(x='Churn', y='Age', data=df[['Age', 'Churn']], palette='Set2', hue= 'Churn')
plt.xlabel('Churn')
plt.ylabel('Age')
plt.title('Age vs Churn')
plt.show()

# %%
display(df[['Gender', 'Churn']])
# Out:
#         Gender  Churn
# 0       Female    1.0
# 1       Female    1.0
# 2       Female    1.0
# 3         Male    1.0
# 4         Male    1.0
# ...        ...    ...
# 440828    Male    0.0
# 440829  Female    0.0
# 440830    Male    0.0
# 440831    Male    0.0
# 440832    Male    0.0
#
# [440833 rows x 2 columns]

# %%
gvc = df[['Gender', 'Churn']]
sns.countplot(x='Gender', hue='Churn', data=gvc)
plt.title('Gender vs Churn')
plt.show()

# %%
display(df[['Tenure', 'Churn']])
tvc = df[['Tenure', 'Churn']]
sns.boxplot(x='Churn', y='Tenure', data=tvc)
plt.title('Tenure vs Churn')
plt.show()
# Out:
#         Tenure  Churn
# 0         39.0    1.0
# 1         49.0    1.0
# 2         14.0    1.0
# 3         38.0    1.0
# 4         32.0    1.0
# ...        ...    ...
# 440828    54.0    0.0
# 440829     8.0    0.0
# 440830    35.0    0.0
# 440831    55.0    0.0
# 440832    48.0    0.0
#
# [440833 rows x 2 columns]

# %%
display(df[['Usage Frequency', 'Churn']])
ufvc = df[['Usage Frequency', 'Churn']]
sns.boxplot(x='Usage Frequency', hue='Churn', data=ufvc)
plt.title('Usage Frequency vs Churn')
plt.show()
sns.histplot(data=ufvc, x="Usage Frequency", hue="Churn", kde=True, element="step")
plt.show()
# Out:
#         Usage Frequency  Churn
# 0                  14.0    1.0
# 1                   1.0    1.0
# 2                   4.0    1.0
# 3                  21.0    1.0
# 4                  20.0    1.0
# ...                 ...    ...
# 440828             15.0    0.0
# 440829             13.0    0.0
# 440830             27.0    0.0
# 440831             14.0    0.0
# 440832             20.0    0.0
#
# [440833 rows x 2 columns]

# %%
display(df[['Support Calls', 'Churn']])
scvc = df[['Support Calls', 'Churn']]
sns.boxplot(x='Support Calls', hue='Churn', data=scvc)
plt.title('Support Calls vs Churn')
plt.show()
# Out:
#         Support Calls  Churn
# 0                 5.0    1.0
# 1                10.0    1.0
# 2                 6.0    1.0
# 3                 7.0    1.0
# 4                 5.0    1.0
# ...               ...    ...
# 440828            1.0    0.0
# 440829            1.0    0.0
# 440830            1.0    0.0
# 440831            2.0    0.0
# 440832            1.0    0.0
#
# [440833 rows x 2 columns]

# %%
display(df[['Payment Delay', 'Churn']])
pdvc = df[['Payment Delay', 'Churn']]
sns.boxplot(x='Payment Delay', hue='Churn', data=pdvc)
plt.title('Payment Delay vs Churn')
plt.show()
# Out:
#         Payment Delay  Churn
# 0                18.0    1.0
# 1                 8.0    1.0
# 2                18.0    1.0
# 3                 7.0    1.0
# 4                 8.0    1.0
# ...               ...    ...
# 440828            3.0    0.0
# 440829           20.0    0.0
# 440830            5.0    0.0
# 440831            0.0    0.0
# 440832           14.0    0.0
#
# [440833 rows x 2 columns]

# %%
display(df[['Subscription Type', 'Churn']])
stvc = df[['Subscription Type', 'Churn']]
sns.countplot(x='Subscription Type', hue='Churn', data=stvc)
plt.title('Subscription Type vs Churn')
# Out:
#        Subscription Type  Churn
# 0               Standard    1.0
# 1                  Basic    1.0
# 2                  Basic    1.0
# 3               Standard    1.0
# 4                  Basic    1.0
# ...                  ...    ...
# 440828           Premium    0.0
# 440829           Premium    0.0
# 440830          Standard    0.0
# 440831          Standard    0.0
# 440832           Premium    0.0
#
# [440833 rows x 2 columns]
# Text(0.5, 1.0, 'Subscription Type vs Churn')

# %%
display(df[['Contract Length', 'Churn']])
clvc = df[['Contract Length', 'Churn']]
sns.countplot(x='Contract Length', hue='Churn', data=clvc)
plt.title('Contract Length vs Churn')
# Out:
#        Contract Length  Churn
# 0               Annual    1.0
# 1              Monthly    1.0
# 2            Quarterly    1.0
# 3              Monthly    1.0
# 4              Monthly    1.0
# ...                ...    ...
# 440828          Annual    0.0
# 440829          Annual    0.0
# 440830       Quarterly    0.0
# 440831       Quarterly    0.0
# 440832       Quarterly    0.0
#
# [440833 rows x 2 columns]
# Text(0.5, 1.0, 'Contract Length vs Churn')

# %%
display(df[['Total Spend', 'Churn']])
tsvc = df[['Total Spend', 'Churn']]
sns.boxplot(x='Total Spend', hue='Churn', data=tsvc)
plt.title('Total Spend vs Churn')
# Out:
#         Total Spend  Churn
# 0            932.00    1.0
# 1            557.00    1.0
# 2            185.00    1.0
# 3            396.00    1.0
# 4            617.00    1.0
# ...             ...    ...
# 440828       716.38    0.0
# 440829       745.38    0.0
# 440830       977.31    0.0
# 440831       602.55    0.0
# 440832       567.77    0.0
#
# [440833 rows x 2 columns]
# Text(0.5, 1.0, 'Total Spend vs Churn')

# %%
display(df[['Last Interaction', 'Churn']])
livc = df[['Last Interaction', 'Churn']]
sns.boxplot(x='Last Interaction', hue='Churn', data=livc)
plt.title('Last Interaction vs Churn')
# Out:
#         Last Interaction  Churn
# 0                   17.0    1.0
# 1                    6.0    1.0
# 2                    3.0    1.0
# 3                   29.0    1.0
# 4                   20.0    1.0
# ...                  ...    ...
# 440828               8.0    0.0
# 440829               2.0    0.0
# 440830               9.0    0.0
# 440831               2.0    0.0
# 440832              21.0    0.0
#
# [440833 rows x 2 columns]
# Text(0.5, 1.0, 'Last Interaction vs Churn')

# %%
df.dtypes
# Out:
# CustomerID           float64
# Age                  float64
# Gender                object
# Tenure               float64
# Usage Frequency      float64
# Support Calls        float64
# Payment Delay        float64
# Subscription Type     object
# Contract Length       object
# Total Spend          float64
# Last Interaction     float64
# Churn                float64
# dtype: object

# %%
#seperate the numerical columns and categorical columns for to fix the null values
numerical_cols = df.select_dtypes(include=['float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
numerical_cols
# Out:
# ['CustomerID',
#  'Age',
#  'Tenure',
#  'Usage Frequency',
#  'Support Calls',
#  'Payment Delay',
#  'Total Spend',
#  'Last Interaction',
#  'Churn']

# %%
categorical_cols
# Out:
# ['Gender', 'Subscription Type', 'Contract Length']

# %%
#replace the NULL values in the numerical col with the mean
for col in numerical_cols:
    mean_value = df[col].mean()
    df[col].fillna(mean_value, inplace=True)
# Out:
# C:\Users\danai\AppData\Local\Temp\ipykernel_1828\3539015193.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(mean_value, inplace=True)

# %%
df[numerical_cols].isnull().sum()
# Out:
# CustomerID          0
# Age                 0
# Tenure              0
# Usage Frequency     0
# Support Calls       0
# Payment Delay       0
# Total Spend         0
# Last Interaction    0
# Churn               0
# dtype: int64

# %%
for col in categorical_cols:
    df.dropna(subset=[col], inplace=True)

# %%
df[categorical_cols].isna().sum()
# Out:
# Gender               0
# Subscription Type    0
# Contract Length      0
# dtype: int64

# %%
#save the cleaned data set
df.to_csv('cleaned_customer_churn_dataset.csv', index=False)

# %%
numerical_cols = df.select_dtypes(include=['float64'])
# visualize the carrelation between the numerical_cols
numerical_cols.corr().round(2)
# Out:
#                   CustomerID   Age  Tenure  Usage Frequency  Support Calls  \
# CustomerID              1.00 -0.18    0.04             0.04          -0.48
# Age                    -0.18  1.00   -0.01            -0.01           0.16
# Tenure                  0.04 -0.01    1.00            -0.03          -0.03
# Usage Frequency         0.04 -0.01   -0.03             1.00          -0.02
# Support Calls          -0.48  0.16   -0.03            -0.02           1.00
# Payment Delay          -0.26  0.06   -0.02            -0.01           0.16
# Total Spend             0.36 -0.08    0.02             0.02          -0.22
# Last Interaction       -0.13  0.03   -0.01            -0.00           0.08
# Churn                  -0.84  0.22   -0.05            -0.05           0.57
#
#                   Payment Delay  Total Spend  Last Interaction  Churn
# CustomerID                -0.26         0.36             -0.13  -0.84
# Age                        0.06        -0.08              0.03   0.22
# Tenure                    -0.02         0.02             -0.01  -0.05
# Usage Frequency           -0.01         0.02             -0.00  -0.05
# Support Calls              0.16        -0.22              0.08   0.57
# Payment Delay              1.00        -0.12              0.04   0.31
# Total Spend               -0.12         1.00             -0.06  -0.43
# Last Interaction           0.04        -0.06              1.00   0.15
# Churn                      0.31        -0.43              0.15   1.00

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(numerical_cols.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df['Churn'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Churn Distribution')
plt.ylabel('')
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
df.groupby(['Churn','Gender'])['Age'].mean().plot(kind='bar')
plt.title('Average Age by Gender and Churn')
plt.xlabel('Gender')
plt.ylabel('Average Age')
plt.show()

# %%
df.groupby('Churn')['Tenure'].mean().plot(kind= 'bar')
plt.title('Average Tenure by Churn')
plt.xlabel('Churn')
plt.ylabel('Average Tenure')
plt.show()

# %%
df.groupby('Churn')['Payment Delay'].mean().plot(kind='bar')
plt.title('Average Payment Delay by Churn')
plt.xlabel('Churn')
plt.ylabel('Average Payment Delay')
plt.show()

# %%
df.groupby('Churn')['Total Spend'].mean().plot(kind='bar')
plt.title('Average Total Spend by Churn')
plt.xlabel('Churn')
plt.ylabel('Average Total Spend')
plt.show()

# %%
df.groupby('Churn')['Support Calls'].mean().plot(kind='bar')
plt.title('Average Support Calls by Churn')
plt.xlabel('Churn')
plt.ylabel('Average Support Calls')
plt.show()

# %%
df.groupby('Churn')['Usage Frequency'].mean().plot(kind='bar')
plt.title('Average Usage Frequency by Churn')
plt.xlabel('Churn')
plt.ylabel('Average Usage Frequency')
plt.show()

# %%
df.groupby('Churn')['Last Interaction'].mean().plot(kind='bar')
plt.title('Average Last Interaction by Churn')
plt.xlabel('Churn')
plt.ylabel('Average Last Interaction')
plt.show()

# %%
df.groupby('Churn')['Contract Length'].value_counts().plot(kind='bar')
plt.title('Average Contract Length by Churn')
plt.xlabel('Churn')
plt.ylabel('Average Contract Length')
plt.show()
